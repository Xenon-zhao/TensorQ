# %%
from tensorq import QuantumCircuit
n=30
m=14
seq='EFGH'
qc = QuantumCircuit(n, m, seq=seq)
# Out:
# type(gates): <class 'list'>
# type(tensors_simp): <class 'list'>
# type(labels_simp): <class 'list'>
# type(qubits_representation): <class 'dict'>

# %%
qc.qubits_representation
# Out:
# {175: [175, 155, 125, 30, 0, 156, 126, 99, 86, 60, 31, 1, 61, 32, 2],
#  176: [176, 157, 129, 102, 158, 130, 103, 88, 64, 35, 5, 65, 36, 6],
#  177: [177, 159, 132, 37, 7, 160, 133, 105, 89, 66, 38, 8, 67, 39, 9],
#  178: [178, 161, 134, 106, 162, 135, 107, 90, 68, 40, 10, 69, 41, 11],
#  179: [179, 163, 138, 110, 164, 139, 111, 92, 72, 44, 14, 73, 45, 15],
#  180: [180, 165, 140, 112, 166, 141, 113, 93, 74, 46, 16, 75, 47, 17],
#  181: [181, 167, 144, 116, 168, 145, 117, 95, 78, 50, 20, 79, 51, 21],
#  182: [182, 169, 146, 118, 170, 147, 52, 22],
#  183: [183, 171, 149, 120, 172, 150, 121, 97, 82, 55, 25, 83, 56, 26],
#  184: [184, 173, 153, 124, 174, 154, 59, 29],
#  259: [259, 235, 208, 128, 101, 87, 62, 33, 3, 63, 34, 4, 236, 213, 190],
#  260: [260, 237, 209, 187, 238, 214, 191],
#  261: [261, 239, 210, 188, 240, 215, 192],
#  262: [262, 241, 211, 131, 104, 242, 216, 136, 108],
#  263: [263,
#   243,
#   217,
#   137,
#   109,
#   91,
#   70,
#   42,
#   12,
#   71,
#   43,
# ...
